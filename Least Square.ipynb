# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('C:/Users/Yoga/Desktop/Dataset.csv')
df_fix = df.fillna(0)
df_fix = df_fix.drop_duplicates()
df_fix = df_fix.loc[:, (df_fix != 0).any(axis=0)]

column_name = df_fix.columns[9:-1].tolist()

jumlah_kolom = int(len(df_fix.columns[9:-1])/2)

jumlah_observasi = df_fix.shape[0] - jumlah_kolom

df_x_function1 = df_fix.iloc[0:(jumlah_kolom),9:-1]
np_array_x1 = df_x_function1.to_numpy()
df_y_function1 = df_fix.iloc[0:(jumlah_kolom),-1:]
np_array_y1 = df_y_function1.to_numpy()
A = np_array_x1
B = np_array_y1
X1 = np.linalg.lstsq(A,B,rcond=None)[0]

X1 = np.hstack(X1)

df_x_function2 = df_fix.iloc[1:(jumlah_kolom+1),9:-1]
np_array_x2 = df_x_function2.to_numpy()
df_y_function2 = df_fix.iloc[1:(jumlah_kolom+1),-1:]
np_array_y2 = df_y_function2.to_numpy()
C = np_array_x2
D = np_array_y2
X2 = np.linalg.lstsq(C,D,rcond=None)[0]

X2 = np.hstack(X2)

df_x_function3 = df_fix.iloc[2:(jumlah_kolom+2),9:-1]
np_array_x3 = df_x_function3.to_numpy()
df_y_function3 = df_fix.iloc[2:(jumlah_kolom+2),-1:]
np_array_y3 = df_y_function3.to_numpy()
E = np_array_x3
F = np_array_y3
X3 = np.linalg.lstsq(E,F,rcond=None)[0]

X3 = np.hstack(X3)

df_x_function4 = df_fix.iloc[3:(jumlah_kolom+3),9:-1]
np_array_x4 = df_x_function4.to_numpy()
df_y_function4 = df_fix.iloc[3:(jumlah_kolom+3),-1:]
np_array_y4 = df_y_function4.to_numpy()
G = np_array_x4
H = np_array_y4
X4 = np.linalg.lstsq(G,H,rcond=None)[0]

X4 = np.hstack(X4)

df_x_function5 = df_fix.iloc[4:(jumlah_kolom+4),9:-1]
np_array_x5 = df_x_function5.to_numpy()
df_y_function5 = df_fix.iloc[4:(jumlah_kolom+4),-1:]
np_array_y5 = df_y_function5.to_numpy()
I = np_array_x5
J = np_array_y5
X5 = np.linalg.lstsq(I,J,rcond=None)[0]

X5 = np.hstack(X5)

df_x_function6 = df_fix.iloc[5:(jumlah_kolom+5),9:-1]
np_array_x6 = df_x_function6.to_numpy()
df_y_function6 = df_fix.iloc[5:(jumlah_kolom+5),-1:]
np_array_y6 = df_y_function6.to_numpy()
K = np_array_x6
L = np_array_y6
X6 = np.linalg.lstsq(K,L,rcond=None)[0]

X6 = np.hstack(X6)

df_x_function7 = df_fix.iloc[6:(jumlah_kolom+6),9:-1]
np_array_x7 = df_x_function7.to_numpy()
df_y_function7 = df_fix.iloc[6:(jumlah_kolom+6),-1:]
np_array_y7 = df_y_function7.to_numpy()
M = np_array_x7
N = np_array_y7
X7 = np.linalg.lstsq(M,N,rcond=None)[0]

X7 = np.hstack(X7)

df_x_function8 = df_fix.iloc[7:(jumlah_kolom+7),9:-1]
np_array_x8 = df_x_function8.to_numpy()
df_y_function8 = df_fix.iloc[7:(jumlah_kolom+7),-1:]
np_array_y8 = df_y_function8.to_numpy()
O = np_array_x8
P = np_array_y8
X8 = np.linalg.lstsq(O,P,rcond=None)[0]

X8 = np.hstack(X8)

df_x_function9 = df_fix.iloc[8:(jumlah_kolom+8),9:-1]
np_array_x9 = df_x_function9.to_numpy()
df_y_function9 = df_fix.iloc[8:(jumlah_kolom+8),-1:]
np_array_y9 = df_y_function9.to_numpy()
Q = np_array_x9
R = np_array_y9
X9 = np.linalg.lstsq(Q,R,rcond=None)[0]

X9 = np.hstack(X9)

df_x_function10 = df_fix.iloc[9:(jumlah_kolom+9),9:-1]
np_array_x10 = df_x_function10.to_numpy()
df_y_function10 = df_fix.iloc[9:(jumlah_kolom+9),-1:]
np_array_y10 = df_y_function10.to_numpy()
S = np_array_x10
T = np_array_y10
X10 = np.linalg.lstsq(S,T,rcond=None)[0]

X10 = np.hstack(X10)

df_x_function11 = df_fix.iloc[10:(jumlah_kolom+10),9:-1]
np_array_x11 = df_x_function11.to_numpy()
df_y_function11 = df_fix.iloc[10:(jumlah_kolom+10),-1:]
np_array_y11 = df_y_function11.to_numpy()
U = np_array_x11
V = np_array_y11
X11 = np.linalg.lstsq(U,V,rcond=None)[0]

X11 = np.hstack(X11)

df_x_function12 = df_fix.iloc[11:(jumlah_kolom+11),9:-1]
np_array_x12 = df_x_function12.to_numpy()
df_y_function12 = df_fix.iloc[11:(jumlah_kolom+11),-1:]
np_array_y12 = df_y_function12.to_numpy()
W = np_array_x12
X = np_array_y12
X12 = np.linalg.lstsq(W,X,rcond=None)[0]

X12 = np.hstack(X12)

df_x_function13 = df_fix.iloc[12:(jumlah_kolom+12),9:-1]
np_array_x13 = df_x_function13.to_numpy()
df_y_function13 = df_fix.iloc[12:(jumlah_kolom+12),-1:]
np_array_y13 = df_y_function13.to_numpy()
Y = np_array_x13
Z = np_array_y13
X13 = np.linalg.lstsq(Y,Z,rcond=None)[0]

X13 = np.hstack(X13)

df_x_function14 = df_fix.iloc[13:(jumlah_kolom+13),9:-1]
np_array_x14 = df_x_function14.to_numpy()
df_y_function14 = df_fix.iloc[13:(jumlah_kolom+13),-1:]
np_array_y14 = df_y_function14.to_numpy()
AA = np_array_x14
AB = np_array_y14
X14 = np.linalg.lstsq(AA,AB,rcond=None)[0]

X14 = np.hstack(X14)

df_x_function15 = df_fix.iloc[14:(jumlah_kolom+14),9:-1]
np_array_x15 = df_x_function15.to_numpy()
df_y_function15 = df_fix.iloc[14:(jumlah_kolom+14),-1:]
np_array_y15 = df_y_function15.to_numpy()
AC = np_array_x15
AD = np_array_y15
X15 = np.linalg.lstsq(AC,AD,rcond=None)[0]

X15 = np.hstack(X15)

df_x_function16 = df_fix.iloc[15:(jumlah_kolom+15),9:-1]
np_array_x16 = df_x_function16.to_numpy()
df_y_function16 = df_fix.iloc[15:(jumlah_kolom+15),-1:]
np_array_y16 = df_y_function16.to_numpy()
AE = np_array_x16
AF = np_array_y16
X16 = np.linalg.lstsq(AE,AF,rcond=None)[0]

X16 = np.hstack(X16)

df_x_function17 = df_fix.iloc[16:(jumlah_kolom+16),9:-1]
np_array_x17 = df_x_function17.to_numpy()
df_y_function17 = df_fix.iloc[16:(jumlah_kolom+16),-1:]
np_array_y17 = df_y_function17.to_numpy()
AG = np_array_x17
AH = np_array_y17
X17 = np.linalg.lstsq(AG,AH,rcond=None)[0]

X17 = np.hstack(X17)

df_x_function18 = df_fix.iloc[17:(jumlah_kolom+17),9:-1]
np_array_x18 = df_x_function18.to_numpy()
df_y_function18 = df_fix.iloc[17:(jumlah_kolom+17),-1:]
np_array_y18 = df_y_function18.to_numpy()
AI = np_array_x18
AJ = np_array_y18
X18 = np.linalg.lstsq(AI,AJ,rcond=None)[0]

X18 = np.hstack(X18)

df_x_function19 = df_fix.iloc[18:(jumlah_kolom+18),9:-1]
np_array_x19 = df_x_function19.to_numpy()
df_y_function19 = df_fix.iloc[18:(jumlah_kolom+18),-1:]
np_array_y19 = df_y_function19.to_numpy()
AK = np_array_x19
AL = np_array_y19
X19 = np.linalg.lstsq(AK,AL,rcond=None)[0]

X19 = np.hstack(X19)

df_x_function20 = df_fix.iloc[19:(jumlah_kolom+19),9:-1]
np_array_x20 = df_x_function20.to_numpy()
df_y_function20 = df_fix.iloc[19:(jumlah_kolom+19),-1:]
np_array_y20 = df_y_function20.to_numpy()
AM = np_array_x20
AN = np_array_y20
X20 = np.linalg.lstsq(AM,AN,rcond=None)[0]

X20 = np.hstack(X20)

df_x_function21 = df_fix.iloc[20:(jumlah_kolom+20),9:-1]
np_array_x21 = df_x_function21.to_numpy()
df_y_function21 = df_fix.iloc[20:(jumlah_kolom+20),-1:]
np_array_y21 = df_y_function21.to_numpy()
AO = np_array_x21
AP = np_array_y21
X21 = np.linalg.lstsq(AO,AP,rcond=None)[0]

X21 = np.hstack(X21)

df_x_function22 = df_fix.iloc[21:(jumlah_kolom+21),9:-1]
np_array_x22 = df_x_function22.to_numpy()
df_y_function22 = df_fix.iloc[21:(jumlah_kolom+21),-1:]
np_array_y22 = df_y_function22.to_numpy()
AQ = np_array_x22
AR = np_array_y22
X22 = np.linalg.lstsq(AQ,AR,rcond=None)[0]

X22 = np.hstack(X22)

df_x_function23 = df_fix.iloc[22:(jumlah_kolom+22),9:-1]
np_array_x23 = df_x_function23.to_numpy()
df_y_function23 = df_fix.iloc[22:(jumlah_kolom+22),-1:]
np_array_y23 = df_y_function23.to_numpy()
AS = np_array_x23
AT = np_array_y23
X23 = np.linalg.lstsq(AS,AT,rcond=None)[0]

X23 = np.hstack(X23)

df_x_function24 = df_fix.iloc[23:(jumlah_kolom+23),9:-1]
np_array_x24 = df_x_function24.to_numpy()
df_y_function24 = df_fix.iloc[23:(jumlah_kolom+23),-1:]
np_array_y24 = df_y_function24.to_numpy()
AU = np_array_x24
AV = np_array_y24
X24 = np.linalg.lstsq(AU,AV,rcond=None)[0]

X24 = np.hstack(X24)

df_x_function25 = df_fix.iloc[24:(jumlah_kolom+24),9:-1]
np_array_x25 = df_x_function25.to_numpy()
df_y_function25 = df_fix.iloc[24:(jumlah_kolom+24),-1:]
np_array_y25 = df_y_function25.to_numpy()
AW = np_array_x25
AX = np_array_y25
X25 = np.linalg.lstsq(AW,AX,rcond=None)[0]

X25 = np.hstack(X25)

df_x_function26 = df_fix.iloc[25:(jumlah_kolom+25),9:-1]
np_array_x26 = df_x_function26.to_numpy()
df_y_function26 = df_fix.iloc[25:(jumlah_kolom+25),-1:]
np_array_y26 = df_y_function26.to_numpy()
AY = np_array_x26
AZ = np_array_y26
X26 = np.linalg.lstsq(AY,AZ,rcond=None)[0]

X26 = np.hstack(X26)

df_x_function27 = df_fix.iloc[26:(jumlah_kolom+26),9:-1]
np_array_x27 = df_x_function27.to_numpy()
df_y_function27 = df_fix.iloc[26:(jumlah_kolom+26),-1:]
np_array_y27 = df_y_function27.to_numpy()
BA = np_array_x27
BB = np_array_y27
X27 = np.linalg.lstsq(BA,BB,rcond=None)[0]

X27 = np.hstack(X27)

df_x_function28 = df_fix.iloc[27:(jumlah_kolom+27),9:-1]
np_array_x28 = df_x_function28.to_numpy()
df_y_function28 = df_fix.iloc[27:(jumlah_kolom+27),-1:]
np_array_y28 = df_y_function28.to_numpy()
BC = np_array_x28
BD = np_array_y28
X28 = np.linalg.lstsq(BC,BD,rcond=None)[0]

X28 = np.hstack(X28)

df_x_function29 = df_fix.iloc[28:(jumlah_kolom+28),9:-1]
np_array_x29 = df_x_function29.to_numpy()
df_y_function29 = df_fix.iloc[28:(jumlah_kolom+28),-1:]
np_array_y29 = df_y_function29.to_numpy()
BE = np_array_x29
BF = np_array_y29
X29 = np.linalg.lstsq(BE,BF,rcond=None)[0]

X29 = np.hstack(X29)

df_x_function30 = df_fix.iloc[29:(jumlah_kolom+29),9:-1]
np_array_x30 = df_x_function30.to_numpy()
df_y_function30 = df_fix.iloc[29:(jumlah_kolom+29),-1:]
np_array_y30 = df_y_function30.to_numpy()
BG = np_array_x30
BH = np_array_y30
X30 = np.linalg.lstsq(BE,BF,rcond=None)[0]

X30 = np.hstack(X30)

results = []
for k in range(1,30):
    results += ['X'+str(k)]

Final = pd.DataFrame(data = [eval(var) for var in results], columns= column_name)

array = Final.to_numpy()
Final_array = np.where((array > 6000) | (array < 3500), np.nan, array)

Final_calculate = pd.DataFrame(data = Final_array, columns = column_name)

Viz = Final_calculate.melt()
Viz2 = Viz.dropna()

Viz3 = Viz2.rename({'variable':'Coal_Source', 'value':'Qual'}, axis=1)

def __repr__(self):
    return '{:.1%}'.format(self)

Numerical_Analysis = pd.DataFrame(data = Viz3.iloc[:,0].unique(), columns=['Coal Source'])
Numerical_Analysis['Sample Count'] = Numerical_Analysis['Coal Source'].map((df_fix.iloc[:,9:-1].gt(0).sum())/df_fix.shape[0])

Sample_Count = []
for k in range(0,Numerical_Analysis.shape[0]):
    Sample_Count += [__repr__(Numerical_Analysis['Sample Count'][k])]

Sample_Size  = pd.DataFrame(Sample_Count, columns = ['Sample Size'])

Final = Numerical_Analysis.join(Sample_Size)
Final = Final.drop('Sample Count',1)
Final
# Out:
#    Coal Source Sample Size
# 0      TPSHICA       81.2%
# 1       TPS300       43.8%
# 2         TPSA       68.8%
# 3      TPSLOCV       20.8%
# 4     TPSLOCTS       37.5%
# 5       PBHICV       52.1%
# 6        PB700       54.2%
# 7          PBA       60.4%
# 8         PBTS       12.5%
# 9        TSC12       79.2%
# 10       TSC13       95.8%
# 11       TSC23       95.8%
# 12      TSN100       33.3%
# 13      BCNLSA       20.8%
# 14          SP       79.2%

# %% [markdown]
# ## GRAPHICAL ANALYSIS

# %%
plt.figure(figsize=(10,4))

sns.boxplot(x="Coal_Source", y="Qual", data=Viz3, showfliers = False, color="skyblue")
plt.xticks(rotation=90)

x=[5150,4800,4600,4450,4125,5450,4825,4650,4500,4750,4600,4600,4750,4700,4850]
plt.plot(x,'r-o',linewidth=3)

# %%
results = []
for k in range(1,30):
    results += ['X'+str(k)]

Final = pd.DataFrame(data = [eval(var) for var in results], columns= column_name)
Final
# Out:
#          TPSHICA        TPS300         TPSA       TPSLOCV     TPSLOCTS  \
# 0   10476.616400  2.828961e+03  6570.665319  4.174703e+02  2218.645735
# 1   10574.411145  2.562672e+03  5722.754971  2.134129e+02  1706.520260
# 2    9987.023683  2.568572e+03  7942.559342  3.661763e+02  3633.002493
# 3    9091.923421  2.645653e+03  8835.656535  6.818965e+02  2497.637331
# 4    9721.771363  3.411058e+03  8407.316496  1.348756e+03  3113.802059
# 5    9909.040648  9.232835e+02  3887.030384  2.479280e+02  3150.094705
# 6    9929.387047 -9.525335e+01  5428.142157 -4.080527e+01  2764.116737
# 7    9413.392714  1.208351e+03  6725.287710 -3.312676e+02    70.276410
# 8   10053.881254 -9.094947e-13  6761.093034 -2.229639e+02  1448.866410
# 9    9753.025251 -2.728484e-12  4199.990179  4.355540e+02  2049.883166
# 10   9977.968144  1.364242e-12  5725.426756  0.000000e+00  3781.258535
# 11  11745.731471  4.547474e-13  7099.749451  1.818989e-12  1912.410720
# ...
